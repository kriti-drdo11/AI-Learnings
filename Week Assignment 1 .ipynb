# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read File
df = pd.read_csv('Dataset/airquality.csv')
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
# number of rows & column
df.shape
# Out:
# (153, 7)

# %%
# name of columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
# rows 10-25
df.iloc[10:25,:]
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 10          11    7.0      NaN   6.9    74      5   11
# 11          12   16.0    256.0   9.7    69      5   12
# 12          13   11.0    290.0   9.2    66      5   13
# 13          14   14.0    274.0  10.9    68      5   14
# 14          15   18.0     65.0  13.2    58      5   15
# 15          16   14.0    334.0  11.5    64      5   16
# 16          17   34.0    307.0  12.0    66      5   17
# 17          18    6.0     78.0  18.4    57      5   18
# 18          19   30.0    322.0  11.5    68      5   19
# 19          20   11.0     44.0   9.7    62      5   20
# 20          21    1.0      8.0   9.7    59      5   21
# 21          22   11.0    320.0  16.6    73      5   22
# 22          23    4.0     25.0   9.7    61      5   23
# 23          24   32.0     92.0  12.0    61      5   24
# 24          25    NaN     66.0  16.6    57      5   25

# %%
# sort using Temp
df.sort_values('Temp')
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 4             5    NaN      NaN  14.3    56      5    5
# 17           18    6.0     78.0  18.4    57      5   18
# 24           25    NaN     66.0  16.6    57      5   25
# 26           27    NaN      NaN   8.0    57      5   27
# 14           15   18.0     65.0  13.2    58      5   15
# ..          ...    ...      ...   ...   ...    ...  ...
# 41           42    NaN    259.0  10.9    93      6   11
# 122         123   85.0    188.0   6.3    94      8   31
# 120         121  118.0    225.0   2.3    94      8   29
# 121         122   84.0    237.0   6.3    96      8   30
# 119         120   76.0    203.0   9.7    97      8   28
#
# [153 rows x 7 columns]

# %%
# farenhite to centigrade
F = df['Temp']
C = (F - 32) * 5/9
C
# Out:
# 0      19.444444
# 1      22.222222
# 2      23.333333
# 3      16.666667
# 4      13.333333
#          ...
# 148    21.111111
# 149    25.000000
# 150    23.888889
# 151    24.444444
# 152    20.000000
# Name: Temp, Length: 153, dtype: float64

# %%
#information of 5th month
df[df['Month'] == 5]
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0            1   41.0    190.0   7.4    67      5    1
# 1            2   36.0    118.0   8.0    72      5    2
# 2            3   12.0    149.0  12.6    74      5    3
# 3            4   18.0    313.0  11.5    62      5    4
# 4            5    NaN      NaN  14.3    56      5    5
# 5            6   28.0      NaN  14.9    66      5    6
# 6            7   23.0    299.0   8.6    65      5    7
# 7            8   19.0     99.0  13.8    59      5    8
# 8            9    8.0     19.0  20.1    61      5    9
# 9           10    NaN    194.0   8.6    69      5   10
# 10          11    7.0      NaN   6.9    74      5   11
# 11          12   16.0    256.0   9.7    69      5   12
# 12          13   11.0    290.0   9.2    66      5   13
# 13          14   14.0    274.0  10.9    68      5   14
# 14          15   18.0     65.0  13.2    58      5   15
# 15          16   14.0    334.0  11.5    64      5   16
# ...

# %%
# question 2
df1 = pd.read_csv('Dataset/cricket.csv')
df1
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0

# %%
df1[['name','runs']]
# Out:
#             name  runs
# 0    Anil Dalpat  6755
# 1   Rohan Kanhay  1256
# 2  Avdhoot Dighe  8954
# 3       Bahubali   756
# 4      Leeladhar  2866
# 5      Pradyumna  5877
# 6     Dinesh Roy  8537
# 7     Parmeshwar  9466
# 8    Ali Durrani  2756
# 9   Litesh Singh  1099

# %%
df1[['name','wickets']]
# Out:
#             name  wickets
# 0    Anil Dalpat       12
# 1   Rohan Kanhay      178
# 2  Avdhoot Dighe        0
# 3       Bahubali       11
# 4      Leeladhar      376
# 5      Pradyumna      122
# 6     Dinesh Roy       16
# 7     Parmeshwar        0
# 8    Ali Durrani       26
# 9   Litesh Singh       49

# %%
# average of cathes
df1['avg']= df1['runs']/df1['catches'] 
df1
df1['catches'].mean
# Out:
# <bound method Series.mean of 0     56
# 1     76
# 2    120
# 3      6
# 4    105
# 5     47
# 6    112
# 7     53
# 8     12
# 9     46
# Name: catches, dtype: int64>

# %%
df1['catches'].mean
# Out:
# <bound method Series.mean of 0     56
# 1     76
# 2    120
# 3      6
# 4    105
# 5     47
# 6    112
# 7     53
# 8     12
# 9     46
# Name: catches, dtype: int64>

# %%
#strikerate
s_rate = (runs / Balls) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #strikerate
# ----> 2 s_rate = (runs / Balls) * 100
#
# NameError: name 'runs' is not defined

# %%
x= df1['matches']
y= df1['runs']
plt.xlabel('matches')
plt.ylabel('runs')
plt.grid()
plt.plot(x,y)

# %%
df1.sort_values(['runs'])
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings  \
# 3      4       Bahubali       10   756        6       11          3
# 9     10   Litesh Singh       89  1099       46       49          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 0      1    Anil Dalpat      122  6755       56       12          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 7      8     Parmeshwar      245  9466       53        0          0
#
#           avg
# 3  126.000000
# 9   23.891304
# 1   16.526316
# 8  229.666667
# 4   27.295238
# 5  125.042553
# 0  120.625000
# 6   76.223214
# 2   74.616667
# 7  178.603774

# %%
df1['name']
# Out:
# 0      Anil Dalpat
# 1     Rohan Kanhay
# 2    Avdhoot Dighe
# 3         Bahubali
# 4        Leeladhar
# 5        Pradyumna
# 6       Dinesh Roy
# 7       Parmeshwar
# 8      Ali Durrani
# 9     Litesh Singh
# Name: name, dtype: object

# %%
a = np.array(df1['wickets'])
a
# Out:
# array([ 12, 178,   0,  11, 376, 122,  16,   0,  26,  49], dtype=int64)

# %%
b = np.array(df1['runs'])

# %%
b
# Out:
# array([6755, 1256, 8954,  756, 2866, 5877, 8537, 9466, 2756, 1099],
#       dtype=int64)

# %%
df1['matches'].max()
# Out:
# 265

# %%
# Players whose wickets are greater than matches
df2 = df1[df1['wickets']>df1['matches']]
df2['name']
# Out:
# 1    Rohan Kanhay
# 3        Bahubali
# 4       Leeladhar
# Name: name, dtype: object

# %%
df2
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings         avg
# 1      2  Rohan Kanhay      144  1256       76      178          0   16.526316
# 3      4      Bahubali       10   756        6       11          3  126.000000
# 4      5     Leeladhar      234  2866      105      376          0   27.295238
