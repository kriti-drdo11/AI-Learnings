# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset/fb.csv')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
# paid and unpaid posts
df['Paid'].value_counts()
# Out:
# Paid
# 0.0    360
# 1.0    139
# Name: count, dtype: int64

# %%
# Display page type, like ,comment, share
df[['Type','Post Month','like','comment','share']]
# Out:
#        Type  Post Month    like  comment  share
# 0     Photo          12    79.0        4   17.0
# 1    Status          12   130.0        5   29.0
# 2     Photo          12    66.0        0   14.0
# 3     Photo          12  1572.0       58  147.0
# 4     Photo          12   325.0       19   49.0
# ..      ...         ...     ...      ...    ...
# 495   Photo           1    53.0        5   26.0
# 496   Photo           1    53.0        0   22.0
# 497   Photo           1    93.0        4   18.0
# 498   Photo           1    91.0        7   38.0
# 499   Photo           1    91.0        0   28.0
#
# [500 rows x 5 columns]

# %%
# avg number of likes in september

# %%
# posts which are link
li = df.groupby('Type')
li.get_group('Link')
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
sh = li.get_group('Video')
sh
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
#total number of shares for video post
sh['share'].sum()
# Out:
# 365.0

# %%
# information of posts where likes >200 & shares >30
x = df[(df['like']>200) & (df['share']>30) ]
x
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 26             138458  Status         2          12             5         11
# 28             138895   Photo         2          12             5          3
# 38             138895  Status         2          12             7          9
# ..                ...     ...       ...         ...           ...        ...
# 464             92079   Photo         1           2             6         13
# 468             91651   Photo         1           2             4         12
# 476             86909   Photo         1           1             6         10
# 480             86909   Photo         2           1             4         11
# 488             85979   Photo         3           1             7         10
#
# ...

# %%
po = df.groupby('Post Month')
nov = po.get_group(11)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 50            138353   Photo         2          11             1          9
# 51            138329   Photo         1          11             1          3
# 52            138329   Photo         1          11             7          9
# 53            138329   Photo         1          11             7          3
# 54            138329   Photo         1          11             6         10
# 55            138329   Video         1          11             6          2
# 56            138329   Photo         1          11             5         11
# 57            138329   Photo         1          11             5          3
# 58            138329   Photo         1          11             4         10
# 59            138329   Photo         1          11             4          3
# 60            138185   Photo         1          11             3         11
# ...
