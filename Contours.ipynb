# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/circle.png',0)

# %%
thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY)[1]

contour, heirarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(img,contour,-1,(0,255,0))

cv2.imshow(' image',img)
cv2.imshow('Threshold image',thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize= (16,9))
plt.subplot(1,2,1)
plt.imshow(img,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(thresh,cmap='gray')

# %%
img = cv2.imread('images/rgy.jpg',0)
thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY)[1]

contour, heirarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(img,contour,-1,(0,255,0))

plt.figure(figsize= (16,9))
plt.subplot(1,2,1)
plt.imshow(img,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(thresh,cmap='gray')

# %%
img = cv2.imread('images/circle.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)[1]

contour, heirarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(img,contour,-1,(0,255,0),2)

plt.figure(figsize= (16,9))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(thresh)

# %%
img = cv2.imread('images/houseright.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)[1]

contour, heirarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2.drawContours(img,contour,-1,(0,255,0),2)

plt.figure(figsize= (16,9))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(thresh)
